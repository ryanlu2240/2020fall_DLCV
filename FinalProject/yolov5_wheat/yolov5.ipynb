# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# 'My Drive'   yolov4_wheat   yolov5

# %%
# !cp -r /mydrive/yolov5/yolov5 .

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !cp /mydrive/yolov5/wheat.yaml wheat.yaml 
# !unzip /mydrive/yolov5/yolov5_data.zip 
# !ls /mydrive/yolov5
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#   inflating: yolov5_data/images/train/8764d55c1.jpg
#   inflating: yolov5_data/images/train/be2ce55d5.jpg
#   inflating: yolov5_data/images/train/763327404.jpg
#   inflating: yolov5_data/images/train/4759e7258.jpg
#   inflating: yolov5_data/images/train/b7c9166b6.jpg
#   inflating: yolov5_data/images/train/7fc9fe138.jpg
#   inflating: yolov5_data/images/train/c988834c9.jpg
#   inflating: yolov5_data/images/train/f21c0d164.jpg
#   inflating: yolov5_data/images/train/f9ece438e.jpg
#   inflating: yolov5_data/images/train/80833051d.jpg
#   inflating: yolov5_data/images/train/ccb8097e3.jpg
#   inflating: yolov5_data/images/train/87c24665e.jpg
#   inflating: yolov5_data/images/train/83bfee8fd.jpg
#   inflating: yolov5_data/images/train/d8616bdd1.jpg
#   inflating: yolov5_data/images/train/fa068329f.jpg
#   inflating: yolov5_data/images/train/b72ba28ed.jpg
#   inflating: yolov5_data/images/train/fd151ae52.jpg
#   inflating: yolov5_data/images/train/4a8b1ad4a.jpg
# ...

# %%
# !pip install -U PyYAML
# Out:
# ...
#      |████████████████████████████████| 276kB 14.7MB/s
# ...
#   Created wheel for PyYAML: filename=PyYAML-5.3.1-cp36-cp36m-linux_x86_64.whl size=44621 sha256=7eb5f5c2ccfef638f5a4a3eff81b4503dc32a1f98c7c9b896173da94be106ef6
#   Stored in directory: /root/.cache/pip/wheels/a7/c1/ea/cf5bd31012e735dc1dfea3131a2d5eae7978b251083d6247bd
# Successfully built PyYAML
# ...
#   Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
# !python train.py --img 1024 --batch 4 --epochs 300 --resume /mydrive/yolov5/backup22/weights/last.pt \
  --data wheat.yaml --cfg models/yolov5x.yaml --name backup22 --project /mydrive/yolov5
# Out:
# Resuming training from /mydrive/yolov5/backup22/weights/last.pt
# Using torch 1.7.0+cu101 CUDA:0 (Tesla T4, 15079.75MB)
#
# Namespace(adam=False, batch_size=4, bucket='', cache_images=False, cfg='', data='wheat.yaml', device='', epochs=300, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[1024, 1024], local_rank=-1, log_artifacts=False, log_imgs=16, multi_scale=False, name='backup2', noautoanchor=False, nosave=False, notest=False, project='/mydrive/yolov5', rect=False, resume=True, save_dir='/mydrive/yolov5/backup22', single_cls=False, sync_bn=False, total_batch_size=4, weights='/mydrive/yolov5/backup22/weights/last.pt', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir /mydrive/yolov5", view at http://localhost:6006/
# 2020-12-29 16:08:10.941149: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# !python train.py --img 1024 --batch 4 --epochs 300 \
  --data wheat.yaml --cfg models/yolov5x.yaml --weights yolov5x.pt \
  --name backup2 --project /mydrive/yolov5
