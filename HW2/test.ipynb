# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 14479, done.
# remote: Total 14479 (delta 0), reused 0 (delta 0), pack-reused 14479
# Receiving objects: 100% (14479/14479), 13.16 MiB | 22.93 MiB/s, done.
# Resolving deltas: 100% (9849/9849), done.

# %%
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/' Makefile
# Out:
# /content/darknet

# %%
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %%
# %cd .. 
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# /content
# Mounted at /content/gdrive

# %%
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
#  2019中資  'Colab Notebooks'  'My Drive'   yolov4

# %%
# %cd darknet
# Out:
# /content/darknet

# %%
# !ls /mydrive/yolov4
# Out:
# backup		   HW2.ipynb  obj.zip	  val.zip
# generate_test.py   obj.data   test.ipynb  yolov4-obj.cfg
# generate_train.py  obj.names  test.zip

# %%
# !cp /mydrive/yolov4/yolov4-obj.cfg ./cfg

# %%
# !cp /mydrive/yolov4/obj.names ./data
# !cp /mydrive/yolov4/obj.data  ./data

# %%
# !cp /mydrive/yolov4/obj.zip ../
# !cp /mydrive/yolov4/test.zip ../

# %%
# !unzip ../obj.zip -d data/
# !unzip ../test.zip -d data/
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#   inflating: data/test/31068.txt
#   inflating: data/test/32885.jpg
#   inflating: data/test/28605.jpg
#   inflating: data/test/27536.jpg
#   inflating: data/test/32561.txt
#   inflating: data/test/31354.jpg
#   inflating: data/test/27622.txt
#   inflating: data/test/32675.jpg
#   inflating: data/test/28511.txt
#   inflating: data/test/31040.txt
#   inflating: data/test/32549.txt
#   inflating: data/test/30062.jpg
#   inflating: data/test/29533.jpg
#   inflating: data/test/33131.txt
#   inflating: data/test/29255.jpg
#   inflating: data/test/27278.jpg
#   inflating: data/test/30704.jpg
#   inflating: data/test/31726.txt
#   inflating: data/test/29169.txt
#   inflating: data/test/32113.jpg
#   inflating: data/test/27144.txt
#   inflating: data/test/28277.txt
#   inflating: data/test/30438.txt
#   inflating: data/test/33219.jpg
#   inflating: data/test/31732.txt
#   inflating: data/test/27150.txt
#   inflating: data/test/32107.jpg
# ...

# %%
# !cp /mydrive/yolov4/generate_train.py ./
# !cp /mydrive/yolov4/generate_test.py ./

# %%
# !python generate_train.py
# !python generate_test.py

# %%
# !ls data/
# Out:
# 9k.tree     eagle.jpg	 imagenet.labels.list	   obj.names	     voc.names
# coco9k.map  giraffe.jpg  imagenet.shortnames.list  openimages.names
# coco.names  goal.txt	 labels			   person.jpg
# dog.jpg     horses.jpg	 obj.data		   scream.jpg

# %%
# !./darknet detector map data/obj.data cfg/yolov4-obj.cfg /mydrive/yolov4/backup/yolov4-obj_6000.weights
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
# ...

# %%
# !cp /mydrive/yolov4/val.zip ../

# %%
# !unzip ../val.zip -d data/
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#   inflating: data/val/10117.png
#   inflating: data/__MACOSX/val/._10117.png
#   inflating: data/val/2450.png
#   inflating: data/__MACOSX/val/._2450.png
#   inflating: data/val/3996.png
#   inflating: data/__MACOSX/val/._3996.png
#   inflating: data/val/4021.png
#   inflating: data/__MACOSX/val/._4021.png
#   inflating: data/val/11209.png
#   inflating: data/__MACOSX/val/._11209.png
#   inflating: data/val/3028.png
#   inflating: data/__MACOSX/val/._3028.png
#   inflating: data/val/4747.png
#   inflating: data/__MACOSX/val/._4747.png
#   inflating: data/val/5459.png
#   inflating: data/__MACOSX/val/._5459.png
#   inflating: data/val/10671.png
#   inflating: data/__MACOSX/val/._10671.png
#   inflating: data/val/2336.png
#   inflating: data/__MACOSX/val/._2336.png
#   inflating: data/val/9263.png
#   inflating: data/__MACOSX/val/._9263.png
#   inflating: data/val/6150.png
#   inflating: data/__MACOSX/val/._6150.png
#   inflating: data/val/12066.png
# ...

# %%
# !python generate_test.py
# !cp /mydrive/yolov4/generate_test.py ./
# Out:
# python3: can't open file 'generate_test.py': [Errno 2] No such file or directory

# %%
# !python generate_test.py

# %%
# !ls data/
# Out:
# 9k.tree     eagle.jpg	 imagenet.labels.list	   obj.data	     scream.jpg
# coco9k.map  giraffe.jpg  imagenet.shortnames.list  obj.names	     val
# coco.names  goal.txt	 labels			   openimages.names  val.txt
# dog.jpg     horses.jpg	 __MACOSX		   person.jpg	     voc.names

# %%
# %cd cfg
# !sed -i 's/batch=64/batch=1/' yolov4-obj.cfg
# !sed -i 's/subdivisions=16/subdivisions=1/' yolov4-obj.cfg
# %cd ..
# Out:
# /content/darknet/cfg
# /content/darknet

# %%
# !./darknet detector test data/obj.data cfg/yolov4-obj.cfg /mydrive/yolov4/backup/yolov4-obj_5000.weights -ext_output -dont_show -out result.json < data/val.txt
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# data/val/7152.png: Predicted in 17.661000 milli-seconds.
# 1: 61%	(left_x:   42   top_y:   13   width:   10   height:   23)
# 9: 78%	(left_x:   51   top_y:   13   width:   12   height:   23)
# 10: 72%	(left_x:   64   top_y:   11   width:   13   height:   24)
# Enter Image Path:  Detection layer: 139 - type = 28
#  Detection layer: 150 - type = 28
#  Detection layer: 161 - type = 28
# data/val/2252.png: Predicted in 17.647000 milli-seconds.
# 9: 70%	(left_x:   32   top_y:    7   width:   10   height:   17)
# 7: 74%	(left_x:   43   top_y:    6   width:    9   height:   19)
# Enter Image Path:  Detection layer: 139 - type = 28
#  Detection layer: 150 - type = 28
#  Detection layer: 161 - type = 28
# data/val/3100.png: Predicted in 17.668000 milli-seconds.
# 1: 40%	(left_x:  121   top_y:   18   width:   13   height:   20)
# 3: 52%	(left_x:  131   top_y:   18   width:   14   height:   21)
# Enter Image Path:  Detection layer: 139 - type = 28
# ...
